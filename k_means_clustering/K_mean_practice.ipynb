# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.cluster import KMeans
# Out:
# C:\Users\Kshitij Vashisth\AppData\Local\Temp\ipykernel_16500\466485351.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
data = np.loadtxt('kmeans_4000.txt')

# %%
data.shape
# Out:
# (4000, 5)

# %%
fig, ax = plt.subplots()
ax.plot(data.T[:,::10])
ax.set_xlabel('Number')
ax.set_ylabel('Brightness')
# Out:
# Text(0, 0.5, 'Brightness')

# %%
k_means_2 = KMeans(n_clusters=2, n_init=10, random_state=0)
k_means_2.fit(data)
# Out:
# KMeans(n_clusters=2, n_init=10, random_state=0)

# %%
cluster_labels_2 = k_means_2.predict(data)

# %%
cluster_img = cluster_labels_2.reshape(ordered_im_stack.shape[1:])

fig, ax = plt.subplots()
cmap = ax.imshow(cluster_img, cmap='bone')
ax.set_title('Cluster Image')
plt.colorbar(cmap, ax=ax)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 cluster_img = cluster_labels_2.reshape(ordered_im_stack.shape[1:])
#       3 fig, ax = plt.subplots()
#       4 cmap = ax.imshow(cluster_img, cmap='bone')
#
# NameError: name 'ordered_im_stack' is not defined

# %%
# Calculate WCSS for different values of k
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', max_iter=300, n_init=10, random_state=0)
    kmeans.fit(data)
    wcss.append(kmeans.inertia_)

# Plot the elbow curve
plt.plot(range(1, 11), wcss)
plt.title('Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()
