# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('megaGymDataset.csv')

# %%
data['BodyPart'].unique()
# Out:
# array(['Abdominals', 'Adductors', 'Abductors', 'Biceps', 'Calves',
#        'Chest', 'Forearms', 'Glutes', 'Hamstrings', 'Lats', 'Lower Back',
#        'Middle Back', 'Traps', 'Neck', 'Quadriceps', 'Shoulders',
#        'Triceps'], dtype=object)

# %%
data.describe()
# Out:
#         Unnamed: 0       Rating
# count  2918.000000  1031.000000
# mean   1458.500000     5.919690
# std     842.498368     3.584607
# min       0.000000     0.000000
# 25%     729.250000     3.000000
# 50%    1458.500000     7.900000
# 75%    2187.750000     8.700000
# max    2917.000000     9.600000

# %%
quadriceps_data = data[data['BodyPart'] == 'Quadriceps']

# %%
quadriceps_data
# Out:
#       Unnamed: 0                                      Title         Type  \
# 1781        1781                     Single-leg depth squat     Strength
# 1782        1782                        Squats - With Bands     Strength
# 1783        1783                      Hip Flexion with Band     Strength
# 1784        1784                          Forward Band Walk     Strength
# 1785        1785  Boss Everline Resistance-Band Pull Sprint     Strength
# ...          ...                                        ...          ...
# 2422        2422                 Smith machine lunge sprint     Strength
# 2423        2423                                Sissy squat     Strength
# 2424        2424                             Wall ball toss  Plyometrics
# 2425        2425                            Bosu Ball Squat     Strength
# 2426        2426        Exercise ball Bulgarian split squat     Strength
#
#         BodyPart      Equipment         Level  Rating RatingDesc Calories
# ...

# %%
data.columns
# Out:
# Index(['Unnamed: 0', 'Title', 'Desc', 'Type', 'BodyPart', 'Equipment', 'Level',
#        'Rating', 'RatingDesc'],
#       dtype='object')

# %%
data = data.drop(columns=['Desc'])
data['Calories'] = ''

# %%
data
# Out:
#       Unnamed: 0                                           Title      Type  \
# 0              0                          Partner plank band row  Strength
# 1              1                    Banded crunch isometric hold  Strength
# 2              2                           FYR Banded Plank Jack  Strength
# 3              3                                   Banded crunch  Strength
# 4              4                                          Crunch  Strength
# ...          ...                                             ...       ...
# 2913        2913                            EZ-bar skullcrusher-  Strength
# 2914        2914  Lying Close-Grip Barbell Triceps Press To Chin  Strength
# 2915        2915          EZ-Bar Skullcrusher - Gethin Variation  Strength
# 2916        2916                                TBS Skullcrusher  Strength
# 2917        2917                     30 Arms EZ-Bar Skullcrusher  Strength
#
# ...

# %%
exercise_name=data['Title'].tolist()

# %%
# Define the file name
file_name = 'exercise_name.txt'

# Open the file in write mode and write each element of the list to the file
with open(file_name, 'a') as file:
    for exercise in exercise_name:
        file.write(exercise + '\n')

# %%
filtered_data = data[data['Title'].str.contains('barbell|dumbbell', case=False)]

# %%
filtered_data
# Out:
#                                               Title      Type BodyPart  \
# 44                     Incline dumbbell biceps curl  Strength   Biceps
# 45                           Wide-grip barbell curl  Strength   Biceps
# 46                                     Barbell Curl  Strength   Biceps
# 47           Barbell Curls Lying Against An Incline  Strength   Biceps
# 48     Seated Close-Grip Concentration Barbell Curl  Strength   Biceps
# ..                                              ...       ...      ...
# 463                   30 Arms Dumbbell Skullcrusher  Strength  Triceps
# 464                      30 Arms Dumbbell Kick-Back  Strength  Triceps
# 465                  30 Arms BFR Dumbbell Kick-Back  Strength  Triceps
# 466               Dumbbell saw triceps skullcrusher  Strength  Triceps
# 467  Lying Close-Grip Barbell Triceps Press To Chin  Strength  Triceps
#
#         Equipment         Level RatingDesc Calories
# 44          Bands  Intermediate        NaN
# ...

# %%
filtered_data = filtered_data.drop(columns=['Unnamed: 0'])

# %%
filtered_data = filtered_data.reset_index(drop=True)

# %%
filtered_data = filtered_data.drop(columns=['Rating'])

# %%
filtered_data = filtered_data[filtered_data['BodyPart'] != 'Abdominals']

# %%
filtered_data.columns
# Out:
# Index(['Title', 'Type', 'BodyPart', 'Equipment', 'Level', 'RatingDesc',
#        'Calories'],
#       dtype='object')

# %%
filtered_data['BodyPart'].unique()
# Out:
# array(['Biceps', 'Calves', 'Chest', 'Forearms', 'Glutes', 'Hamstrings',
#        'Lats', 'Lower Back', 'Middle Back', 'Traps', 'Quadriceps',
#        'Shoulders', 'Triceps'], dtype=object)

# %%
filtered_data[filtered_data['BodyPart']=='Lats']
# Out:
#                                                  Title      Type BodyPart  \
# 183                         Bent-arm barbell pull-over  Strength     Lats
# 184                         Barbell pull-over to press  Strength     Lats
# 185                   Single-arm barbell bent-over row  Strength     Lats
# 186                                Reverse Barbell Row  Strength     Lats
# 187                                  Dumbbell seal row  Strength     Lats
# 188            Incline Dumbbell Row - Gethin Variation  Strength     Lats
# 189                         FYR Bent-Over Dumbbell Row  Strength     Lats
# 190  Straight-Arm Dumbbell Pull-Over - Gethin Varia...  Strength     Lats
# 191          Bent-Over Dumbbell Row - Gethin Variation  Strength     Lats
# 192                   Bent-over dumbbell rear delt fly  Strength     Lats
# 193                         Band Resisted Dumbbell Row  Strength     Lats
# 194          Total Fitness Dumbbell Isometric Row Hold  Strength     Lats
# ...

# %%
len(filtered_data[filtered_data['BodyPart']=='Lats'])
# Out:
# 14

# %%
filtered_data.to_csv('picked_exercises.csv')

# %%
filtered_data = filtered_data.drop(data.columns[0], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[49], line 1
# ----> 1 filtered_data = filtered_data.drop(data.columns[0], axis=1)
#
# File C:\AI\miniforge\envs\spyder\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File C:\AI\miniforge\envs\spyder\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
# ...

# %%
filtered_data
# Out:
#                                               Title      Type BodyPart  \
# 0                      Incline dumbbell biceps curl  Strength   Biceps
# 1                            Wide-grip barbell curl  Strength   Biceps
# 2                                      Barbell Curl  Strength   Biceps
# 3            Barbell Curls Lying Against An Incline  Strength   Biceps
# 4      Seated Close-Grip Concentration Barbell Curl  Strength   Biceps
# ..                                              ...       ...      ...
# 419                   30 Arms Dumbbell Skullcrusher  Strength  Triceps
# 420                      30 Arms Dumbbell Kick-Back  Strength  Triceps
# 421                  30 Arms BFR Dumbbell Kick-Back  Strength  Triceps
# 422               Dumbbell saw triceps skullcrusher  Strength  Triceps
# 423  Lying Close-Grip Barbell Triceps Press To Chin  Strength  Triceps
#
#         Equipment         Level RatingDesc Calories
# 0           Bands  Intermediate        NaN
# ...

# %%
filtered_data = filtered_data.reset_index(drop=True)

# %%
filtered_data
# Out:
#                                               Title      Type BodyPart  \
# 0                      Incline dumbbell biceps curl  Strength   Biceps
# 1                            Wide-grip barbell curl  Strength   Biceps
# 2                                      Barbell Curl  Strength   Biceps
# 3            Barbell Curls Lying Against An Incline  Strength   Biceps
# 4      Seated Close-Grip Concentration Barbell Curl  Strength   Biceps
# ..                                              ...       ...      ...
# 419                   30 Arms Dumbbell Skullcrusher  Strength  Triceps
# 420                      30 Arms Dumbbell Kick-Back  Strength  Triceps
# 421                  30 Arms BFR Dumbbell Kick-Back  Strength  Triceps
# 422               Dumbbell saw triceps skullcrusher  Strength  Triceps
# 423  Lying Close-Grip Barbell Triceps Press To Chin  Strength  Triceps
#
#         Equipment         Level RatingDesc Calories
# 0           Bands  Intermediate        NaN
# ...

# %%
filtered_data.reset_index(drop=True, inplace=True)

# %%
filtered_data
# Out:
#                                               Title      Type BodyPart  \
# 0                      Incline dumbbell biceps curl  Strength   Biceps
# 1                            Wide-grip barbell curl  Strength   Biceps
# 2                                      Barbell Curl  Strength   Biceps
# 3            Barbell Curls Lying Against An Incline  Strength   Biceps
# 4      Seated Close-Grip Concentration Barbell Curl  Strength   Biceps
# ..                                              ...       ...      ...
# 419                   30 Arms Dumbbell Skullcrusher  Strength  Triceps
# 420                      30 Arms Dumbbell Kick-Back  Strength  Triceps
# 421                  30 Arms BFR Dumbbell Kick-Back  Strength  Triceps
# 422               Dumbbell saw triceps skullcrusher  Strength  Triceps
# 423  Lying Close-Grip Barbell Triceps Press To Chin  Strength  Triceps
#
#         Equipment         Level RatingDesc Calories
# 0           Bands  Intermediate        NaN
# ...

# %%
filtered_data['Level'].value_counts()
# Out:
# Intermediate    369
# Beginner         53
# Expert            2
# Name: Level, dtype: int64

# %%
filtered_data[filtered_data['Level']=='Expert']
# Out:
#                      Title      Type    BodyPart Equipment   Level RatingDesc  \
# 210  Barbell forward lunge  Strength  Quadriceps   Barbell  Expert    Average
# 213     Barbell hack squat  Strength  Quadriceps   Barbell  Expert    Average
#
#     Calories
# 210
# 213
